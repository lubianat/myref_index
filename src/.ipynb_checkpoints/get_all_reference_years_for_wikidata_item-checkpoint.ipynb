# %% [markdown]
# Median Year of References - Another innovation index
#
#
# The general goal is to build an innovation index based on a very simple principle: the median year of the citations in an article.
#
# The rationale is that higher median years would indicate an active field of work, which may be a proxy for wheter an article is "innovative".
#
# We will gather the data from Wikidata for the year 2017.
#
#
# The first task is:  extract all years for all references in a given article.
#
# Article of choice for testing: Q22330722 (Potential sexual transmission of Zika virus)

# %%
from wikidataintegrator import wdi_core

test_article_item = wdi_core.WDItemEngine(wd_item_id='Q22330722')

# %%
import json

import numpy as np

vint = np.vectorize(int)
article_json =  test_article_item.get_wd_json_representation()

print()

all_years = []
for reference in article_json['claims']['P2860']:
    qid_reference = reference['mainsnak']['datavalue']['value']['id']
    reference_json =  wdi_core.WDItemEngine(wd_item_id=qid_reference).get_wd_json_representation()
    year = reference_json['claims']['P577'][0]['mainsnak']['datavalue']['value']['time'][1:5]
    all_years.append(year)
    np.median(all_years)

print(all_years)
# Out:
# ['1952', '2014', '2014', '2014', '2014', '2014', '2011', '2009', '2009', '2013', '2012', '2009', '2005', '1977', '2010']

# %% [markdown]
# Now let's organize this into a function:
#
# given a QID, the function will return the median year of the references of the article.

# %%
from wikidataintegrator import wdi_core
import json
import numpy as np

def median_year_reference(qid):

    vint = np.vectorize(int)
    
    test_article_item = wdi_core.WDItemEngine(wd_item_id=qid)
    article_json =  test_article_item.get_wd_json_representation()
    
    all_years = []
    for reference in article_json['claims']['P2860']:
        qid_reference = reference['mainsnak']['datavalue']['value']['id']
        reference_json =  wdi_core.WDItemEngine(wd_item_id=qid_reference).get_wd_json_representation()
        year = reference_json['claims']['P577'][0]['mainsnak']['datavalue']['value']['time'][1:5]
        all_years.append(year)
    
    all_years = vint(all_years)
    
    return(np.median(all_years))

median_year_reference("Q22330722")
# Out:
# 2011.0

# %% [markdown]
# Okay, it is working, now I'm just going to test a simple hypothesis:
#
# is the myref index correlated with citations?
#
#
# For this, I will get the QIDs for Nature articles published in 2015 in the Wikidata database:

# %%
query = '''
SELECT ?item ?itemLabel WHERE {
  # ?item wdt:P1433 wd:Q180445.
  # ?item wdt:P31 wd:Q13442814.
  # ?item wdt:P2860 ?ref.
  # ?item  wdt:P577 ?date.
  FILTER(?date > "2014-12-31T23:59:59Z"^^xsd:dateTime)
  FILTER(?date < "2016-01-01T00:00:00Z"^^xsd:dateTime)
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  
}

'''

result = wdi_core.WDItemEngine.execute_sparql_query(query)

# %%
result_list = result['results']['bindings']

newlist = []
for i in result_list:
      if i not in newlist:
            newlist.append(i)
            
result_list = newlist

# %%
mini_result_list = result_list[0:10]

# %%
import time as time


time_before = time.time()

article_myref = dict()

for result in mini_result_list:
    qid = result['item']['value'].split('/')[4]
    print(qid)
    article_myref[qid] = median_year_reference(qid)
    
print(time.time() - time_before )
# Out:
# Q22251076
# Q22251077
# Q20666131
# Q21505108
# Q21534936
# Q22122124
# Q22122126
# Q22122127
# Q22305005
# Q22337241
# 458.24058985710144

# %%
import time as time
time.time()
for result in mini_result_list:
    qid = result['item']['value'].split('/')[4]
    print(result['itemLabel']['value'])
# Out:
# Substantial contribution of extrinsic risk factors to cancer development
# Evidence for human transmission of amyloid-β pathology and cerebral amyloid angiopathy
# A bizarre Jurassic maniraptoran theropod with preserved evidence of membranous wings
# Observation of the rare Bs0 →µ+µ− decay from the combined analysis of CMS and LHCb data
# Massive migration from the steppe was a source for Indo-European languages in Europe
# Hemichordate genomes and deuterostome origins
# Plant biology: Coding in non-coding RNAs
# The octopus genome and the evolution of cephalopod neural and morphological novelties
# Genetic studies of body mass index yield new insights for obesity biology
# Reducing neurodevelopmental disorders and disability through research and interventions

# %%
import scholarly
search_query = scholarly.search_pubs_query('Perception of physical stability and center of mass of 3D objects')

print(next(search_query))
# Out:
# {'_filled': False,
#  'bib': {'abstract': 'Humans can judge from vision alone whether an object is '
#                      'physically stable or not. Such judgments allow observers '
#                      'to predict the physical behavior of objects, and hence '
#                      'to guide their motor actions. We investigated the visual '
#                      'estimation of physical stability of 3-D objects (shown '
#                      'in stereoscopically viewed rendered scenes) and how it '
#                      'relates to visual estimates of their center of mass '
#                      '(COM). In Experiment 1, observers viewed an object near '
#                      'the edge of a table and adjusted its tilt to the '
#                      'perceived critical angle, ie, the tilt angle at which '
#                      'the object …',
#          'author': 'SA Cholewiak and RW Fleming and M Singh',
#          'eprint': 'https://jov.arvojournals.org/article.aspx?articleID=2213254',
#          'title': 'Perception of physical stability and center of mass of 3-D '
#                   'objects',
#          'url': 'https://jov.arvojournals.org/article.aspx?articleID=2213254'},
#  'source': 'scholar'}

# %% [markdown]
# This approach is ok, but we have 2 problems:
#  * The function takes too long
#  * The scholarly module does not return citations anymore
#
# Let's build a smarter SPARQL query to automatically get all dates

# %%
query = '''
SELECT ?item ?itemLabel ?year ?pubmedid WHERE {
  # ?item wdt:P1433 wd:Q180445.
  # ?item wdt:P31 wd:Q13442814.
  # ?item wdt:P2860 ?ref.
  # ?ref wdt:P577 ?year.
  # ?item wdt:P698 ?pubmedid.
  # ?item  wdt:P577 ?date.
  
  FILTER(?date > "2014-12-31T23:59:59Z"^^xsd:dateTime)
  FILTER(?date < "2016-01-01T00:00:00Z"^^xsd:dateTime)
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  
}


'''

result = wdi_core.WDItemEngine.execute_sparql_query(query)

# %%
print(type(df.iloc[1,1]))



def get_value(binding):
    
    value = binding['value']
    
    if "http://" in value:
        value = value.split("/")[4]
    if "00:00" in value:
        value = int(value[0:4])

    
    return(value)
# Out:
# <class 'dict'>

# %%
import json
import pandas as pd

df = pd.DataFrame.from_dict(result['results']['bindings'])

clean_df = df.applymap(get_value)
myref_table = clean_df.groupby('itemLabel').median()

myref_table.index.name = 'title'
myref_table.reset_index(inplace=True)

myref_table
# Out:
#                                                   title    year
# 0     2015 awards: China Nobel stirs up attack on ac...  2014.0
# 1     3.3-million-year-old stone tools from Lomekwi ...  2006.0
# 2     A Cretaceous eutriconodont and integument evol...  2008.0
# 3     A LAIR1 insertion generates broadly reactive a...  2008.0
# 4     A Mercury-like component of early Earth yields...  2005.0
# 5     A bizarre Jurassic maniraptoran theropod with ...  2007.0
# 6     A circuit mechanism for differentiating positi...  2007.0
# 7                 A colloidal quantum dot spectrometer.  2006.0
# 8     A comprehensive phylogeny of birds (Aves) usin...  2011.0
# 9     A concise synthesis of (+)-batzelladine B from...  2006.0
# 10    A cytosolic network suppressing mitochondria-m...  2009.0
# 11    A direct GABAergic output from the basal gangl...  2005.5
# 12                                 A disease of growth.  2011.5
# 13    A disintegrating minor planet transiting a whi...  2007.0
# 14    A focus on adolescence to reduce neurological,...  2012.0
# 15    A four-helix bundle stores copper for methane ...  2009.0
# 16    A giant protogalactic disk linked to the cosmi...  2013.0
# 17    A global perspective on the influence of envir...  2011.0
# 18       A global reference for human genetic variation  2012.0
# 19    A gp130-Src-YAP module links inflammation to e...  2010.0
# 20    A hemi-fission intermediate links two mechanis...  2010.0
# 21    A human tRNA synthetase is a potent PARP1-acti...  2009.0
# 22    A large-scale dynamo and magnetoturbulence in ...  2006.0
# 23    A marine biogenic source of atmospheric ice-nu...  2011.0
# 24    A mechanism for expansion of regulatory T-cell...  2011.0
# 25    A mechanism for the suppression of homologous ...  2012.0
# 26    A model of breast cancer heterogeneity reveals...  2010.0
# 27    A model-tested North Atlantic Oscillation reco...  2011.0
# 28    A molecular mechanism of artemisinin resistanc...  2010.0
# 29    A motor cortex circuit for motor planning and ...  2011.0
# ...                                                 ...     ...
# 1129  Urban observatories: city data can inform deci...  2012.0
# 1130  Vehicle emissions: Diesel pollution long under...  2015.0
# 1131  Vertically transmitted faecal IgA levels deter...  2010.0
# 1132  Viraemia suppressed in HIV-1-infected humans b...  2013.0
# 1133  Viral-genetic tracing of the input-output orga...  2010.0
# 1134          Visible-frequency hyperbolic metasurface.  2010.0
# 1135  Visualizing transient Watson-Crick-like mispai...  2006.0
# 1136  Volcanic-plutonic parity and the differentiati...  1999.5
# 1137  Warm-hot baryons comprise 5-10 per cent of fil...  2007.5
# 1138            Water: A drought plan for biodiversity.  2005.0
# 1139              Water: Halt India's groundwater loss.  2009.0
# 1140  Western US intermountain seismicity caused by ...  2011.0
# 1141  Whole genomes redefine the mutational landscap...  2011.0
# 1142  Whole-genome characterization of chemoresistan...  2011.0
# 1143  Whole-genome sequencing identifies EN1 as a de...  2010.5
# 1144  Widespread exploitation of the honeybee by ear...  2011.0
# 1145                           Wild bees: Lone rangers.  2015.0
# 1146  Wild-type microglia do not reverse pathology i...  2012.0
# 1147  Wind from the black-hole accretion disk drivin...  2013.0
# 1148                                  Woo et al. reply.  2012.5
# 1149  X-ray structure of a mammalian stearoyl-CoA de...  2004.0
# 1150  YAP is essential for tissue tension to ensure ...  2010.0
# 1151  Yap-dependent reprogramming of Lgr5(+) stem ce...  2011.5
# 1152                                Zanne et al. reply.  2004.5
# 1153  eIF3 targets cell-proliferation messenger RNAs...  2010.0
# 1154  hiCLIP reveals the in vivo atlas of mRNA secon...  2011.0
# 1155  α-Synuclein strains cause distinct synucleinop...  2012.0
# 1156  β-Lactam formation by a non-ribosomal peptide ...  2008.0
# 1157  η-Secretase processing of APP inhibits neurona...  2006.0
# 1158  ∆F508 CFTR interactome remodelling promotes re...  2006.0
#
# [1159 rows x 2 columns]

# %% [markdown]
# Hooray. Problem 1 solved.
#
# For the google scholar problem, I'm gonna do some scraping by hand.

# %%
import requests
from bs4 import BeautifulSoup
import spacy
nlp = spacy.load('en_core_web_sm')


def get_gs_citations(title):
    gs_query = title.replace(" ", "+")
    page = requests.get('https://scholar.google.com.br/scholar?hl=en&as_sdt=0%2C5&q=' + gs_query + '&btnG=')
    
    soup = BeautifulSoup(page.text, 'html.parser')
    citation_list = soup.select("#gs_res_ccl_mid > div > div.gs_ri > div.gs_fl > a:nth-child(3)")
    
    if len(citation_list):
        citation_text = citation_list[0].text
    else:
        return(0)
    if citation_text == "Related articles":
        return(0)

    doc = nlp(citation_text)
    citations = int(doc[2].text)

    return(citations)

# %%
gs_cites = [] asd a21
for title in myref_table["title"]:
    print(title)
    gs_cites.append(get_gs_citations(title))
# Out:
#   File "<ipython-input-299-77edf4f3e8d2>", line 1
#     gs_cites = [] asd a21
#                     ^
# SyntaxError: invalid syntax

# %%
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html>
# <head><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="initial-scale=1" name="viewport"/><title>https://scholar.google.com.br/scholar?hl=en&amp;as_sdt=0%2C5&amp;q=%E2%88%86F508+CFTR+interactome+remodelling+promotes+rescue+of+cystic+fibrosis.&amp;btnG=</title></head>
# <body onload="e=document.getElementById('captcha');if(e){e.focus();}" style="font-family: arial, sans-serif; background-color: #fff; color: #000; padding:20px; font-size:18px;">
# <div style="max-width:400px;">
# <hr noshade="" size="1" style="color:#ccc; background-color:#ccc;"/><br/>
# <form action="index" id="captcha-form" method="post">
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <script>var submitCallback = function(response) {document.getElementById('captcha-form').submit();};</script>
# <div class="g-recaptcha" data-callback="submitCallback" data-s="PFVJpfVkMj-g0Al_NsM-_GF5UH5SU-Pcq8bkqMtsQuh4fL0ydb407NcDlG6VRjkyhG7dwJWSlTS-KPAQAh-URYAE9Xt4uAnZDoOdhRIIXp6D05pyXn6PHMDrSArK_2_UWnIAKaHWhPmysKim27pLfRRZMpR_qeQd-iRFQjIcFJsDaZWyPYrG68AAmDRaTnV4JHYv8u0WOyB0XSY71l_7bRDUmHgHpdQyNkxV5LZiEjyfdNW5m3Um5Jk" data-sitekey="6LfwuyUTAAAAAOAmoS0fdqijC2PbbdH4kjq62Y1b" id="recaptcha"></div>
# <input name="q" type="hidden" value="EgSPa5FCGI3A2-4FIhkA8aeDSxckkykGatjR6DTTeDGB3L7iWpEeMgFy"/><input name="continue" type="hidden" value="https://scholar.google.com.br/scholar?hl=en&amp;as_sdt=0%2C5&amp;q=%E2%88%86F508+CFTR+interactome+remodelling+promotes+rescue+of+cystic+fibrosis.&amp;btnG="/>
# </form>
# <hr noshade="" size="1" style="color:#ccc; background-color:#ccc;"/>
# <div style="font-size:13px;">
# <b>About this page</b><br/><br/>
#
# Our systems have detected unusual traffic from your computer network.  This page checks to see if it's really you sending the requests, and not a robot.  <a href="#" onclick="document.getElementById('infoDiv').style.display='block';">Why did this happen?</a><br/><br/>
# <div id="infoDiv" style="display:none; background-color:#eee; padding:10px; margin:0 0 15px 0; line-height:1.4em;">
# This page appears when Google automatically detects requests coming from your computer network which appear to be in violation of the <a href="//www.google.com/policies/terms/">Terms of Service</a>. The block will expire shortly after those requests stop.  In the meantime, solving the above CAPTCHA will let you continue to use our services.<br/><br/>This traffic may have been sent by malicious software, a browser plug-in, or a script that sends automated requests.  If you share your network connection, ask your administrator for help — a different computer using the same IP address may be responsible.  <a href="//support.google.com/websearch/answer/86640">Learn more</a><br/><br/>Sometimes you may be asked to solve the CAPTCHA if you are using advanced terms that robots are known to use, or sending requests very quickly.
# </div>
#
# IP address: 143.107.145.66<br/>Time: 2019-11-21T19:05:50Z<br/>URL: https://scholar.google.com.br/scholar?hl=en&amp;as_sdt=0%2C5&amp;q=%E2%88%86F508+CFTR+interactome+remodelling+promotes+rescue+of+cystic+fibrosis.&amp;btnG=<br/>
# </div>
# </div>
# </body>
# </html>
#
# []

# %% [markdown]
# It worked until Google Scholar stopped my searches due to too much traffic. I'm going to try Europe PMC API w/ medline, then.

# %%
myref_table = clean_df.groupby(['itemLabel', 'pubmedid']).median().reset_index()


myref_table
# Out:
#                                               itemLabel  pubmedid    year
# 0     2015 awards: China Nobel stirs up attack on ac...  26511571  2014.0
# 1     3.3-million-year-old stone tools from Lomekwi ...  25993961  2006.0
# 2     A Cretaceous eutriconodont and integument evol...  26469049  2008.0
# 3     A LAIR1 insertion generates broadly reactive a...  26700814  2008.0
# 4     A Mercury-like component of early Earth yields...  25877203  2005.0
# 5     A bizarre Jurassic maniraptoran theropod with ...  25924069  2007.0
# 6     A circuit mechanism for differentiating positi...  25925480  2007.0
# 7                 A colloidal quantum dot spectrometer.  26135449  2006.0
# 8     A comprehensive phylogeny of birds (Aves) usin...  26444237  2011.0
# 9     A concise synthesis of (+)-batzelladine B from...  26375010  2006.0
# 10    A cytosolic network suppressing mitochondria-m...  26192197  2009.0
# 11    A direct GABAergic output from the basal gangl...  25739505  2005.5
# 12                                 A disease of growth.  25970455  2011.5
# 13    A disintegrating minor planet transiting a whi...  26490620  2007.0
# 14    A focus on adolescence to reduce neurological,...  26580322  2012.0
# 15    A four-helix bundle stores copper for methane ...  26308900  2009.0
# 16    A giant protogalactic disk linked to the cosmi...  26245373  2013.0
# 17    A global perspective on the influence of envir...  26580326  2011.0
# 18       A global reference for human genetic variation  26432245  2012.0
# 19    A gp130-Src-YAP module links inflammation to e...  25731159  2010.0
# 20    A hemi-fission intermediate links two mechanis...  26123023  2010.0
# 21    A human tRNA synthetase is a potent PARP1-acti...  25533949  2009.0
# 22    A large-scale dynamo and magnetoturbulence in ...  26618868  2006.0
# 23    A marine biogenic source of atmospheric ice-nu...  26354482  2011.0
# 24    A mechanism for expansion of regulatory T-cell...  26605529  2011.0
# 25    A mechanism for the suppression of homologous ...  26649820  2012.0
# 26    A model of breast cancer heterogeneity reveals...  25855289  2010.0
# 27    A model-tested North Atlantic Oscillation reco...  26135450  2011.0
# 28    A molecular mechanism of artemisinin resistanc...  25874676  2010.0
# 29    A motor cortex circuit for motor planning and ...  25731172  2011.0
# ...                                                 ...       ...     ...
# 1129  Urban observatories: city data can inform deci...  25788090  2012.0
# 1130  Vehicle emissions: Diesel pollution long under...  26450046  2015.0
# 1131  Vertically transmitted faecal IgA levels deter...  25686606  2010.0
# 1132  Viraemia suppressed in HIV-1-infected humans b...  25855300  2013.0
# 1133  Viral-genetic tracing of the input-output orga...  26131933  2010.0
# 1134          Visible-frequency hyperbolic metasurface.  26062510  2010.0
# 1135  Visualizing transient Watson-Crick-like mispai...  25762137  2006.0
# 1136  Volcanic-plutonic parity and the differentiati...  26178961  1999.5
# 1137  Warm-hot baryons comprise 5-10 per cent of fil...  26632589  2007.5
# 1138            Water: A drought plan for biodiversity.  25993951  2005.0
# 1139              Water: Halt India's groundwater loss.  25993949  2009.0
# 1140  Western US intermountain seismicity caused by ...  26310767  2011.0
# 1141  Whole genomes redefine the mutational landscap...  25719666  2011.0
# 1142  Whole-genome characterization of chemoresistan...  26017449  2011.0
# 1143  Whole-genome sequencing identifies EN1 as a de...  26367794  2010.5
# 1144  Widespread exploitation of the honeybee by ear...  26560301  2011.0
# 1145                           Wild bees: Lone rangers.  25992676  2015.0
# 1146  Wild-type microglia do not reverse pathology i...  25993969  2012.0
# 1147  Wind from the black-hole accretion disk drivin...  25810204  2013.0
# 1148                                  Woo et al. reply.  26432255  2012.5
# 1149  X-ray structure of a mammalian stearoyl-CoA de...  26098370  2004.0
# 1150  YAP is essential for tissue tension to ensure ...  25778702  2010.0
# 1151  Yap-dependent reprogramming of Lgr5(+) stem ce...  26503053  2011.5
# 1152                                Zanne et al. reply.  25993971  2004.5
# 1153  eIF3 targets cell-proliferation messenger RNAs...  25849773  2010.0
# 1154  hiCLIP reveals the in vivo atlas of mRNA secon...  25799984  2011.0
# 1155  α-Synuclein strains cause distinct synucleinop...  26061766  2012.0
# 1156  β-Lactam formation by a non-ribosomal peptide ...  25624104  2008.0
# 1157  η-Secretase processing of APP inhibits neurona...  26322584  2006.0
# 1158  ∆F508 CFTR interactome remodelling promotes re...  26618866  2006.0
#
# [1159 rows x 3 columns]

# %%
import requests
from bs4 import BeautifulSoup
import spacy
nlp = spacy.load('en_core_web_sm')


def get_pmc_citations(pubmedid):
    page = requests.get('https://www.ebi.ac.uk/europepmc/webservices/rest/MED/' + pubmedid +'/citations?page=1&pageSize=25&format=xml')
    soup = BeautifulSoup(page.text)
    citations = soup.html.body.hitcount.text
    citations = int(citations)
    return(citations)

# %%
europe_pmc_cites = []
for pubmedid in myref_table["pubmedid"]:

    cit = get_pmc_citations(pubmedid)
    print(pubmedid + ": " + str(cit) + " citations")
    europe_pmc_cites.append(cit)
# Out:
# 26511571: 1 citations
# 25993961: 90 citations
# 26469049: 13 citations
# 26700814: 43 citations
# 25877203: 2 citations
# 25924069: 28 citations
# 25925480: 149 citations
# 26135449: 38 citations
# 26444237: 273 citations
# 26375010: 9 citations
# 26192197: 66 citations
# 25739505: 84 citations
# 25970455: 7 citations
# 26490620: 3 citations
# 26580322: 23 citations
# 26308900: 26 citations
# 26245373: 0 citations
# 26580326: 8 citations
# 26432245: 2720 citations
# 25731159: 153 citations
# 26123023: 36 citations
# 25533949: 47 citations
# 26618868: 3 citations
# 26354482: 42 citations
# 26605529: 44 citations
# 26649820: 151 citations
# 25855289: 104 citations
# 26135450: 15 citations
# 25874676: 170 citations
# 25731172: 104 citations
# 25896325: 100 citations
# 26061765: 43 citations
# 26352477: 45 citations
# 25903628: 70 citations
# 26040722: 47 citations
# 26416757: 58 citations
# 26085270: 116 citations
# 26570997: 63 citations
# 26085272: 1 citations
# 25561176: 2 citations
# 26017312: 99 citations
# 25855458: 6 citations
# 25877200: 66 citations
# 25653000: 9 citations
# 26214737: 93 citations
# 26375004: 55 citations
# 26308893: 144 citations
# 25539085: 5 citations
# 25993962: 3 citations
# 26432247: 72 citations
# 25600268: 113 citations
# 26580155: 2 citations
# 25707797: 125 citations
# 25686604: 134 citations
# 26632590: 2 citations
# 25799994: 127 citations
# 25832403: 3 citations
# 25762276: 0 citations
# 25855449: 0 citations
# 25832400: 0 citations
# 26135444: 0 citations
# 25807488: 11 citations
# 26700807: 71 citations
# 26083745: 0 citations
# 26416731: 38 citations
# 25652996: 25 citations
# 26659188: 30 citations
# 26062502: 0 citations
# 25567273: 1 citations
# 25567271: 1 citations
# 25731168: 114 citations
# 26580020: 16 citations
# 25925479: 27 citations
# 25607371: 103 citations
# 26178955: 0 citations
# 25970457: 4 citations
# 26017444: 70 citations
# 25629092: 35 citations
# 26245571: 0 citations
# 26153859: 169 citations
# 26672783: 1 citations
# 26436451: 98 citations
# 26245377: 80 citations
# 26131934: 1 citations
# 26085262: 0 citations
# 26135443: 4 citations
# 26672787: 7 citations
# 26040881: 0 citations
# 26381989: 0 citations
# 25731169: 94 citations
# 25971512: 50 citations
# 26503054: 0 citations
# 26536955: 0 citations
# 26178963: 56 citations
# 26466569: 102 citations
# 25607368: 52 citations
# 25799992: 163 citations
# 26222026: 45 citations
# 25470060: 71 citations
# 25754329: 567 citations
# 26511573: 0 citations
# 26689365: 82 citations
# 26098367: 0 citations
# 26675735: 27 citations
# 26266985: 103 citations
# 26223624: 46 citations
# 26331540: 31 citations
# 26153863: 104 citations
# 25607355: 10 citations
# 25607356: 100 citations
# 25581790: 128 citations
# 25961086: 1 citations
# 25739632: 37 citations
# 26237408: 12 citations
# 25970246: 37 citations
# 26098366: 45 citations
# 26289204: 32 citations
# 26580321: 24 citations
# 25830889: 73 citations
# 26245376: 5 citations
# 25903623: 13 citations
# 26580328: 6 citations
# 25739503: 176 citations
# 26040720: 176 citations
# 26214738: 55 citations
# 26017443: 8 citations
# 26268190: 32 citations
# 26605521: 1 citations
# 26381982: 1 citations
# 25788093: 7 citations
# 26641313: 29 citations
# 25855459: 96 citations
# 26633632: 117 citations
# 26322585: 11 citations
# 26649825: 10 citations
# 26062496: 10 citations
# 26490608: 0 citations
# 26108842: 1 citations
# 26040886: 1 citations
# 26630597: 1 citations
# 25383537: 246 citations
# 26268182: 0 citations
# 26605526: 36 citations
# 26503048: 30 citations
# 26581284: 0 citations
# 26017452: 36 citations
# 26266980: 39 citations
# 26416733: 113 citations
# 25855294: 107 citations
# 25561175: 210 citations
# 26399834: 3 citations
# 26289197: 0 citations
# 26289198: 0 citations
# 25807487: 1 citations
# 26659187: 1 citations
# 25903626: 14 citations
# 26017445: 38 citations
# 26672781: 10 citations
# 26580162: 1 citations
# 25970456: 5 citations
# 26381976: 0 citations
# 25642964: 3 citations
# 25778704: 55 citations
# 25731173: 55 citations
# 26416753: 91 citations
# 26245375: 183 citations
# 26649824: 8 citations
# 26135447: 2 citations
# 25822792: 4 citations
# 25874677: 1 citations
# 26135451: 58 citations
# 26536110: 110 citations
# 26390152: 24 citations
# 26178956: 0 citations
# 25985178: 43 citations
# 25778701: 18 citations
# 25673414: 62 citations
# 26287463: 55 citations
# 26633624: 41 citations
# 25799995: 51 citations
# 26375009: 100 citations
# 26416748: 227 citations
# 26083756: 297 citations
# 25853476: 52 citations
# 26302297: 15 citations
# 25642962: 11 citations
# 26268193: 129 citations
# 26580018: 49 citations
# 25903631: 31 citations
# 26390153: 12 citations
# 25600269: 93 citations
# 26258298: 26 citations
# 26490621: 8 citations
# 26633764: 39 citations
# 26268192: 1 citations
# 26416728: 48 citations
# 26331541: 119 citations
# 26266977: 476 citations
# 26466567: 34 citations
# 26258299: 29 citations
# 25624101: 33 citations
# 26580007: 47 citations
# 25807485: 149 citations
# 26560025: 23 citations
# 26701056: 6 citations
# 25739502: 30 citations
# 25624099: 65 citations
# 26153860: 58 citations
# 25693565: 105 citations
# 26168401: 190 citations
# 26367798: 137 citations
# 26550828: 52 citations
# 25652997: 54 citations
# 26672784: 1 citations
# 26649822: 10 citations
# 26675736: 209 citations
# 26524530: 847 citations
# 25855299: 10 citations
# 25822790: 91 citations
# 26416730: 8 citations
# 25799997: 87 citations
# 26450056: 12 citations
# 26083743: 48 citations
# 26570999: 0 citations
# 26607546: 101 citations
# 26659181: 7 citations
# 26633767: 26 citations
# 26649827: 120 citations
# 26450057: 11 citations
# 26147082: 76 citations
# 25788090: 1 citations
# 26450046: 3 citations
# 25686606: 62 citations
# 25855300: 266 citations
# 26131933: 137 citations
# 26062510: 46 citations
# 25762137: 59 citations
# 26178961: 13 citations
# 26632589: 0 citations
# 25993951: 1 citations
# 25993949: 0 citations
# 26310767: 2 citations
# 25719666: 625 citations
# 26017449: 354 citations
# 26367794: 140 citations
# 26560301: 10 citations
# 25992676: 1 citations
# 25993969: 53 citations
# 25810204: 1 citations
# 26432255: 0 citations
# 26098370: 44 citations
# 25778702: 78 citations
# 26503053: 104 citations
# 25993971: 1 citations
# 25849773: 92 citations
# 25799984: 90 citations
# 26061766: 316 citations
# 25624104: 36 citations
# 26322584: 118 citations
# 26618866: 58 citations

# %%
myref_table["eupcm_citations"] = europe_pmc_cites

# %%
f = open('myref_table.txt', 'w')
f.write(tabulate(myref_table))
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-348-9b5ca93ab561> in <module>()
#       1 f = open('myref_table.txt', 'w')
# ----> 2 f.write(tabulate(myref_table))
#       3 f.close()
#
# NameError: name 'tabulate' is not defined

# %%
myref_table.to_csv(r'../myref_table_nature_2015.csv')

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import pearsonr, spearmanr

plt.plot(myref_table['year'], myref_table['eupcm_citations'], 'ro', alpha = 0.2)


corr, _ = pearsonr(myref_table['year'], myref_table['eupcm_citations'])
print('Pearsons correlation: %.3f' % corr)


corr2, _ = spearmanr(myref_table['year'], myref_table['eupcm_citations'])
print('Spearmans correlation: %.3f' % corr2)
# Out:
# Pearsons correlation: 0.006
# Spearmans correlation: -0.269

# %%
import seaborn as sns

ax = sns.boxplot(x='year', y='eupcm_citations', data=myref_table)
ax.set_yscale("log")

# %% [markdown]
# Wow! I actually expected that the number of citations would be higher for articles that cite more recent work. However, I found no evidence for that.
#
# THe high scoring points towards the right are likely to be only a side effect of having more points towards the right in total.

# %% [markdown]
# Conclusion:
#
# For our sampling, the median year of references is not correlated to how cited a paper is in the following years.
#
# (For Nature papers published in 2015)
